# %% [markdown]
# ## Data Ingestion

# %%
## Document Datastructure

from langchain_core.documents import Document

# %%
doc = Document(
    page_content="this is the main text content that will be used to implement RAG ",
    metadata = {
        "source":"example.txt",
        "pages":1,
        "author":"Krish Naik",
        "date_created":"25-01-2025"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Krish Naik', 'date_created': '25-01-2025'}, page_content='this is the main text content that will be used to implement RAG ')

# %%
## create a simple txt file
import os 
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts = {
    "../data/text_files/python_intro.txt":"""Introduction to Python

Python is a high-level, interpreted programming language known for its simple syntax and readability. It is widely used in web development, data science, machine learning, automation, scripting, and software development.

## Why Python is Popular:

* Easy to learn and beginner-friendly
* Large ecosystem of libraries and frameworks
* Cross-platform support
* Strong community support
* Useful in AI, ML, data analysis, and web development

## Basic Example:

```python
print("Hello, World!")
```

## Variables:

Python allows dynamic typing:

```python
name = "Alice"
age = 21
height = 5.7
```

## Data Types:

* `int` → Integer values
* `float` → Decimal values
* `str` → Strings/text
* `bool` → Boolean values (`True`/`False`)
* `list` → Ordered collection
* `tuple` → Immutable collection
* `dict` → Key-value pairs
* `set` → Unique elements collection

## Control Flow:

```python
if age > 18:
    print("Adult")
else:
    print("Minor")
```

## Loops:

```python
for i in range(5):
    print(i)
```

Output:

```text
0
1
2
3
4
```

## Functions:

```python
def greet(name):
    return f"Hello, {name}"
```

Example:

```python
message = greet("Alice")
print(message)
```

Output:

```text
Hello, Alice
```

## Conclusion:

Python is an excellent first programming language because of its readability, simplicity, and versatility. It is widely used in industry and research across domains such as web development, artificial intelligence, machine learning, data science, automation, and software engineering.

"""}

for filepath,content in sample_texts.items():
    with open(filepath , 'w' , encoding="utf-8") as f:
        f.write(content)

print("sample file text created !")
# Out:
# sample file text created !

# %%
## Text loader
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")
document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Introduction to Python\n\nPython is a high-level, interpreted programming language known for its simple syntax and readability. It is widely used in web development, data science, machine learning, automation, scripting, and software development.\n\n## Why Python is Popular:\n\n* Easy to learn and beginner-friendly\n* Large ecosystem of libraries and frameworks\n* Cross-platform support\n* Strong community support\n* Useful in AI, ML, data analysis, and web development\n\n## Basic Example:\n\n```python\nprint("Hello, World!")\n```\n\n## Variables:\n\nPython allows dynamic typing:\n\n```python\nname = "Alice"\nage = 21\nheight = 5.7\n```\n\n## Data Types:\n\n* `int` → Integer values\n* `float` → Decimal values\n* `str` → Strings/text\n* `bool` → Boolean values (`True`/`False`)\n* `list` → Ordered collection\n* `tuple` → Immutable collection\n* `dict` → Key-value pairs\n* `set` → Unique elements collect
# ...

# %%
## Directory Loader

from langchain_community.document_loaders import DirectoryLoader

dir_loader = DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt",
    loader_cls= TextLoader,
    loader_kwargs={'encoding':'utf-8'},
    show_progress=False
)

document = dir_loader.load()
document
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Introduction to Python\n\nPython is a high-level, interpreted programming language known for its simple syntax and readability. It is widely used in web development, data science, machine learning, automation, scripting, and software development.\n\n## Why Python is Popular:\n\n* Easy to learn and beginner-friendly\n* Large ecosystem of libraries and frameworks\n* Cross-platform support\n* Strong community support\n* Useful in AI, ML, data analysis, and web development\n\n## Basic Example:\n\n```python\nprint("Hello, World!")\n```\n\n## Variables:\n\nPython allows dynamic typing:\n\n```python\nname = "Alice"\nage = 21\nheight = 5.7\n```\n\n## Data Types:\n\n* `int` → Integer values\n* `float` → Decimal values\n* `str` → Strings/text\n* `bool` → Boolean values (`True`/`False`)\n* `list` → Ordered collection\n* `tuple` → Immutable collection\n* `dict` → Key-value pairs\n* `set` → Unique elements coll
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader , PyMuPDFLoader

dir_loader = DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf",
    loader_cls= PyMuPDFLoader,
    show_progress=False
)

pdf_documents = dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'TeX', 'creationdate': '2026-03-25T17:29:50+00:00', 'source': '..\\data\\pdf\\Research Paper Type 1.pdf', 'file_path': '..\\data\\pdf\\Research Paper Type 1.pdf', 'total_pages': 3, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-03-25T17:29:50+00:00', 'trapped': '', 'modDate': 'D:20260325172950Z', 'creationDate': 'D:20260325172950Z', 'page': 0}, page_content='Neuro-Adaptive Ensemble Framework for\nEEG-Based Emotion Recognition\nBhanu Kumar Dev, Adarsh Kumar, Ashish Yadav, Aman Sinha, Kanishka, Srijan\nSchool of Computer Engineering\nKIIT Deemed to be University\nBhubaneswar, Odisha, India\nDr. Sricheta Parui\nSchool of Computer Engineering\nKIIT Deemed to be University\nBhubaneswar, Odisha, India\nAbstract—Emotion recognition using physiological signals is\na rapidly expanding area in affective computing. While single-\nclassifier machine learning models have shown promise in 
# ...
